# %%
import tensorflow as tf
from tensorflow import keras
from utils import process_w2v_data     
from visual import show_w2v_word_embedding  

corpus = [
    # numbers
    "5 2 4 8 6 2 3 6 4",
    "4 8 5 6 9 5 5 6",
    "1 1 5 2 3 3 8",
    "3 6 9 6 8 7 4 6 3",
    "8 9 9 6 1 4 3 4",
    "1 0 2 0 2 1 3 3 3 3 3",
    "9 3 3 0 1 4 7 8",
    "9 9 8 5 6 7 1 2 3 0 1 0",

    # alphabets, expecting that 9 is close to letters
    "a t g q e h 9 u f",
    "e q y u o i p s",
    "q o 9 p l k j o k k o p",
    "h g y i u t t a e q",
    "i k d q r e 9 e a d",
    "o p d g 9 s a f g a",
    "i u y g h k l a s w",
    "o l u y a o g f s",
    "o p i u y g d a s j d l",
    "u k i l o 9 l j s",
    "y g i s h k j l f r f",
    "i o h n 9 9 d 9 f a 9",
]


class SkipGram(keras.Model):
    def __init__(self, v_dim, emb_dim):
        super().__init__()
        self.v_dim = v_dim
        self.embeddings = keras.layers.Embedding(
            input_dim=v_dim, output_dim=emb_dim,       # [n_vocab, emb_dim]
            embeddings_initializer=keras.initializers.RandomNormal(0., 0.1),
        )

        # noise-contrastive estimation
        self.nce_w = self.add_weight(
            name="nce_w", shape=[v_dim, emb_dim],
            initializer=keras.initializers.TruncatedNormal(0., 0.1))  # [n_vocab, emb_dim]
        self.nce_b = self.add_weight(
            name="nce_b", shape=(v_dim,),
            initializer=keras.initializers.Constant(0.1))  # [n_vocab, ]

        self.opt = keras.optimizers.Adam(0.01)

    def call(self, x, training=None, mask=None):
        # x.shape = [n, ]
        o = self.embeddings(x)      # [n, emb_dim]
        return o

    # negative sampling: take one positive label and num_sampled negative labels to compute the loss
    # in order to reduce the computation of full softmax
    def loss(self, x, y, training=None):
        embedded = self.call(x, training)
        return tf.reduce_mean(
            tf.nn.nce_loss(
                weights=self.nce_w, biases=self.nce_b, labels=tf.expand_dims(y, axis=1),
                inputs=embedded, num_sampled=5, num_classes=self.v_dim))

    def step(self, x, y):
        with tf.GradientTape() as tape:
            loss = self.loss(x, y, True)
            grads = tape.gradient(loss, self.trainable_variables)
        self.opt.apply_gradients(zip(grads, self.trainable_variables))
        return loss.numpy()


def train(model, data):
    for t in range(2500):
        bx, by = data.sample(8)
        loss = model.step(bx, by)
        if t % 200 == 0:
            print("step: {} | loss: {}".format(t, loss))


if __name__ == "__main__":
    d = process_w2v_data(corpus, skip_window=2, method="skip_gram")
    m = SkipGram(d.num_word, 2)
    train(m, d)

    # plotting
    show_w2v_word_embedding(m, d, "./visual/results/skipgram.png")
# Out:
# all vocabularies sorted from more frequent to less frequent:
#  ['9' '3' 'o' '6' 'a' '1' 'i' 'g' 's' '4' 'l' 'k' '8' 'u' '2' 'd' '5' 'y'
#  'f' 'e' 'h' 'p' 'q' '0' 'j' '7' 't' 'r' 'w' 'n']
# 5 example pairs:
#  [[16 14]
#  [16  9]
#  [14 16]
#  [14  9]
#  [14 12]]
# step: 0 | loss: 8.560566902160645
# step: 200 | loss: 4.138829231262207
# step: 400 | loss: 2.5566511154174805
# step: 600 | loss: 2.9477686882019043

# %%
from __future__ import division, print_function, absolute_import
import collections
import os
import random
import urllib
import zipfile
from urllib.request import urlretrieve
import numpy as np
import tensorflow as tf
tf.compat.v1.reset_default_graph


learning_rate = 0.1
batch_size = 128
num_steps = 100000
display_step = 10000
eval_step = 5000


eval_words = ['five', 'of', 'going', 'hardware', 'american', 'britain']


embedding_size = 128 
max_vocabulary_size = 50000 
min_occurrence = 10  
skip_window = 1 
num_skips = 2 
num_sampled = 64

# %%
url = 'http://mattmahoney.net/dc/text8.zip'
data_path = 'text8.zip'
if not os.path.exists(data_path):
    print("Downloading the dataset... (It may take some time)")
    filename, _ = urllib.urlretrieve(url, data_path)
    print("Done!")

with zipfile.ZipFile(data_path) as f:
    text_words = f.read(f.namelist()[0]).decode('utf8').lower().split()

# %%
count = [('UNK', -1)]

count.extend(collections.Counter(text_words).most_common(max_vocabulary_size - 1))

for i in range(len(count) - 1, -1, -1):
    if count[i][1] < min_occurrence:
        count.pop(i)
    else:

        break

vocabulary_size = len(count)

word2id = dict()
for i, (word, _)in enumerate(count):
    word2id[word] = i

data = list()
unk_count = 0
for word in text_words:

    index = word2id.get(word, 0)
    if index == 0:
        unk_count += 1
    data.append(index)
count[0] = ('UNK', unk_count)
id2word = dict(zip(word2id.values(), word2id.keys()))

print("Words count:", len(text_words))
print("Unique words:", len(set(text_words)))
print("Vocabulary size:", vocabulary_size)
print("Most common words:", count[:10])
# Out:
# Words count: 17005207
# Unique words: 253854
# Vocabulary size: 47135
# Most common words: [('UNK', 444176), ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]

# %%
data_index = 0

def next_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)

    span = 2 * skip_window + 1
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer.extend(data[0:span])
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1

    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
with tf.device('/cpu:0'):

    embedding = tf.Variable(tf.random.normal([vocabulary_size, embedding_size]))

    nce_weights = tf.Variable(tf.random.normal([vocabulary_size, embedding_size]))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

def get_embedding(x):
    with tf.device('/cpu:0'):

        x_embed = tf.nn.embedding_lookup(embedding, x)
        return x_embed

def nce_loss(x_embed, y):
    with tf.device('/cpu:0'):

        y = tf.cast(y, tf.int64)
        loss = tf.reduce_mean(
            tf.nn.nce_loss(weights=nce_weights,
                           biases=nce_biases,
                           labels=y,
                           inputs=x_embed,
                           num_sampled=num_sampled,
                           num_classes=vocabulary_size))
        return loss

# 评估
def evaluate(x_embed):
    with tf.device('/cpu:0'):

        x_embed = tf.cast(x_embed, tf.float32)
        x_embed_norm = x_embed / tf.sqrt(tf.reduce_sum(tf.square(x_embed)))
        embedding_norm = embedding / tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keepdims=True), tf.float32)
        cosine_sim_op = tf.matmul(x_embed_norm, embedding_norm, transpose_b=True)
        return cosine_sim_op


optimizer = tf.optimizers.SGD(learning_rate)

# %%
def run_optimization(x, y):
    with tf.device('/cpu:0'):

        with tf.GradientTape() as g:
            emb = get_embedding(x)
            loss = nce_loss(emb, y)

        gradients = g.gradient(loss, [embedding, nce_weights, nce_biases])

        optimizer.apply_gradients(zip(gradients, [embedding, nce_weights, nce_biases]))

# %%
# print(word2id)
x_test = np.array([word2id[str(w)] for w in eval_words])

for step in range(1, num_steps + 1):
    batch_x, batch_y = next_batch(batch_size, num_skips, skip_window)
    run_optimization(batch_x, batch_y)

    if step % display_step == 0 or step == 1:
        loss = nce_loss(get_embedding(batch_x), batch_y)
        print("step: %i, loss: %f" % (step, loss))

    if step % eval_step == 0 or step == 1:
        print("Evaluation...")
        sim = evaluate(get_embedding(x_test)).numpy()
        for i in range(len(eval_words)):
            top_k = 8 
            nearest = (-sim[i, :]).argsort()[1:top_k + 1]
            log_str = '"%s" nearest neighbors:' % eval_words[i]
            for k in range(top_k):
                log_str = '%s %s,' % (log_str, id2word[nearest[k]])
            print(log_str)
# Out:
# step: 1, loss: 462.917206
# Evaluation...
# "five" nearest neighbors: elsa, intuitively, phoebe, turret, dialysis, conflicted, surveyor, szko,
# "of" nearest neighbors: algebraic, haworth, shawnee, wisconsin, goodall, homophobic, concur, cobbler,
# "going" nearest neighbors: rembrandt, faraway, ayrton, osh, unmarked, decimus, longing, clearwater,
# "hardware" nearest neighbors: multihull, refused, archiepiscopal, roslin, franciscan, invaders, undertaken, dealerships,
# "american" nearest neighbors: brava, favoring, starship, wittgenstein, conglomerate, sided, raps, awry,
# "britain" nearest neighbors: virginal, hus, transboundary, caracalla, musings, gravis, deneb, emphasis,
# Evaluation...
# "five" nearest neighbors: two, three, four, six, eight, zero, by, one,
# "of" nearest neighbors: the, and, in, to, a, that, it, is,
# "going" nearest neighbors: longing, ayrton, concerti, hidden, osh, rembrandt, decimus, ectopic,
# "hardware" nearest neighbors: refused, multihull, archiepiscopal, undertaken, franciscan, invaders, dealerships, roslin,
# "american" nearest neighbors: on, have, at, an, was, are, this, with,
# "britain" nearest neighbors: hus, virginal, musings, called, females, transboundary, emphasis, deneb,
# step: 10000, loss: 114.938866
# Evaluation...
# "five" nearest neighbors: four, seven, six, three, two, eight, with, was,
# "of" nearest neighbors: the, and, a, to, in, by, with, was,
# "going" nearest neighbors: longing, concerti, hidden, nottinghamshire, surpass, lending, decimus, western,
# "hardware" nearest neighbors: refused, trade, external, multihull, invaders, franciscan, republic, undertaken,
# "american" nearest neighbors: with, from, or, this, s, seven, an, zero,
# "britain" nearest neighbors: called, became, hus, out, virginal, victory, even, when,
# Evaluation...
# "five" nearest neighbors: six, four, three, seven, two, eight, from, at,
# "of" nearest neighbors: the, and, to, in, UNK, by, is, was,
# "going" nearest neighbors: longing, western, hidden, nottinghamshire, concerti, surpass, director, large,
# "hardware" nearest neighbors: refused, trade, external, you, republic, british, man, control,
# "american" nearest neighbors: four, or, were, seven, at, which, three, nine,
# "britain" nearest neighbors: called, became, out, even, when, john, more, see,
# step: 20000, loss: 82.880226
# Evaluation...
# "five" nearest neighbors: four, six, eight, seven, three, one, two, zero,
# "of" nearest neighbors: the, in, and, a, for, on, which, s,
# "going" nearest neighbors: western, large, union, director, longing, march, political, hidden,
# "hardware" nearest neighbors: refused, trade, republic, external, you, control, forces, british,
# "american" nearest neighbors: but, which, or, for, were, other, on, that,
# "britain" nearest neighbors: called, became, out, even, all, when, john, more,
# Evaluation...
# "five" nearest neighbors: four, six, three, eight, two, seven, one, zero,
# "of" nearest neighbors: the, in, a, and, to, by, from, for,
# "going" nearest neighbors: western, large, union, political, years, without, during, great,
# "hardware" nearest neighbors: british, several, so, while, man, who, UNK, with,
# "american" nearest neighbors: their, all, which, on, but, for, other, or,
# "britain" nearest neighbors: called, became, out, two, john, however, after, often,
# step: 30000, loss: 71.248421
# Evaluation...
# "five" nearest neighbors: four, six, three, seven, two, eight, one, zero,
# "of" nearest neighbors: and, in, the, to, a, on, by, was,
# "going" nearest neighbors: western, large, union, years, during, political, great, without,
# "hardware" nearest neighbors: british, while, so, several, where, man, a, and,
# "american" nearest neighbors: or, on, an, and, at, he, his, their,
# "britain" nearest neighbors: became, called, out, john, often, even, after, however,
# Evaluation...
# "five" nearest neighbors: four, six, three, seven, two, one, eight, nine,
# "of" nearest neighbors: in, and, the, an, to, is, on, a,
# "going" nearest neighbors: western, large, union, years, great, during, without, found,
# "hardware" nearest neighbors: british, several, while, so, where, man, part, external,
# "american" nearest neighbors: an, on, s, for, in, their, from, or,
# "britain" nearest neighbors: became, called, out, john, often, after, even, may,
# step: 40000, loss: 22.171215
# Evaluation...
# "five" nearest neighbors: four, three, six, two, seven, eight, one, zero,
# "of" nearest neighbors: in, the, a, and, is, to, on, for,
# "going" nearest neighbors: western, large, found, during, great, years, so, without,
# "hardware" nearest neighbors: several, man, where, so, part, while, british, external,
# "american" nearest neighbors: for, on, which, an, their, his, or, were,
# "britain" nearest neighbors: called, became, out, often, john, after, may, however,
# Evaluation...
# "five" nearest neighbors: four, six, three, two, seven, eight, one, zero,
# "of" nearest neighbors: in, and, the, by, that, this, which, on,
# "going" nearest neighbors: western, large, found, during, great, so, political, years,
# "hardware" nearest neighbors: several, man, part, where, so, external, you, control,
# "american" nearest neighbors: an, which, on, its, or, from, that, by,
# "britain" nearest neighbors: called, became, out, often, john, even, people, may,
# step: 50000, loss: 38.670452
# Evaluation...
# "five" nearest neighbors: four, six, three, two, eight, seven, one, zero,
# "of" nearest neighbors: for, in, and, the, this, on, by, a,
# "going" nearest neighbors: western, large, found, name, years, during, great, political,
# "hardware" nearest neighbors: several, part, man, you, where, external, so, city,
# "american" nearest neighbors: or, for, and, on, its, an, UNK, in,
# "britain" nearest neighbors: became, called, out, often, john, people, use, even,
# Evaluation...
# "five" nearest neighbors: four, six, three, two, eight, one, seven, zero,
# "of" nearest neighbors: in, this, and, to, for, their, which, is,
# "going" nearest neighbors: western, large, found, name, years, great, books, during,
# "hardware" nearest neighbors: several, part, man, you, where, external, forces, trade,
# "american" nearest neighbors: which, an, from, in, or, with, and, UNK,
# "britain" nearest neighbors: became, called, out, often, john, people, use, even,
# step: 60000, loss: 34.522789
# Evaluation...
# "five" nearest neighbors: four, six, three, two, seven, eight, one, zero,
# "of" nearest neighbors: in, a, is, and, but, that, the, for,
# "going" nearest neighbors: western, found, large, name, books, use, march, years,
# "hardware" nearest neighbors: several, you, part, man, trade, forces, control, external,
# "american" nearest neighbors: the, for, that, in, an, from, are, which,
# "britain" nearest neighbors: called, became, out, often, people, john, use, members,
# Evaluation...
# "five" nearest neighbors: four, three, six, two, seven, one, eight, zero,
# "of" nearest neighbors: in, and, a, to, for, or, this, from,
# "going" nearest neighbors: western, found, name, large, books, march, political, use,
# "hardware" nearest neighbors: part, man, several, trade, you, forces, control, son,
# "american" nearest neighbors: and, from, for, that, on, or, which, an,
# "britain" nearest neighbors: became, called, out, often, people, john, use, members,
# step: 70000, loss: 15.156450
# Evaluation...
# "five" nearest neighbors: four, three, six, two, eight, seven, one, zero,
# "of" nearest neighbors: in, and, a, the, some, his, but, or,
# "going" nearest neighbors: western, found, name, large, march, books, use, great,
# "hardware" nearest neighbors: part, trade, man, you, several, UNK, control, forces,
# "american" nearest neighbors: in, or, on, for, were, its, some, from,
# "britain" nearest neighbors: became, called, out, members, use, often, john, people,
# Evaluation...
# "five" nearest neighbors: four, three, six, seven, two, eight, one, zero,
# "of" nearest neighbors: the, in, this, and, a, for, from, but,
# "going" nearest neighbors: western, found, name, march, large, books, use, book,
# "hardware" nearest neighbors: part, trade, man, you, several, control, forces, son,
# "american" nearest neighbors: and, by, from, some, on, were, or, its,
# "britain" nearest neighbors: became, called, out, members, john, people, use, german,
# step: 80000, loss: 28.153690
# Evaluation...
# "five" nearest neighbors: six, four, three, seven, two, eight, one, zero,
# "of" nearest neighbors: in, for, and, or, but, their, at, its,
# "going" nearest neighbors: western, found, name, march, books, large, use, book,
# "hardware" nearest neighbors: part, trade, man, you, several, control, son, forces,
# "american" nearest neighbors: by, s, at, was, that, some, were, which,
# "britain" nearest neighbors: became, called, out, members, john, come, people, german,
# Evaluation...
# "five" nearest neighbors: four, six, three, seven, two, eight, one, zero,
# "of" nearest neighbors: and, in, by, at, but, for, this, on,
# "going" nearest neighbors: western, found, name, march, books, use, large, book,
# "hardware" nearest neighbors: part, trade, man, several, you, son, control, forces,
# "american" nearest neighbors: by, that, at, in, were, and, when, this,
# "britain" nearest neighbors: became, called, members, out, come, german, work, university,
# step: 90000, loss: 54.702293
# Evaluation...
# "five" nearest neighbors: four, six, three, seven, eight, two, one, zero,
# "of" nearest neighbors: in, and, on, or, for, by, its, but,
# "going" nearest neighbors: western, found, name, march, books, use, large, used,
# "hardware" nearest neighbors: part, trade, man, several, you, son, forces, control,
# "american" nearest neighbors: by, some, were, which, from, or, who, for,
# "britain" nearest neighbors: became, called, members, come, out, german, university, thought,
# Evaluation...
# "five" nearest neighbors: four, three, six, seven, eight, two, zero, one,
# "of" nearest neighbors: by, and, from, in, their, for, on, or,
# "going" nearest neighbors: western, found, march, name, books, use, used, large,
# "hardware" nearest neighbors: part, trade, man, several, you, son, forces, control,
# "american" nearest neighbors: and, by, s, or, were, from, some, at,
# "britain" nearest neighbors: became, come, called, thought, members, possible, university, work,
# step: 100000, loss: 24.316719
# Evaluation...
# "five" nearest neighbors: four, three, six, seven, eight, two, one, zero,
# "of" nearest neighbors: in, for, and, the, on, a, by, this,
# "going" nearest neighbors: western, found, march, name, books, used, use, australia,
# "hardware" nearest neighbors: part, trade, man, you, son, several, forces, form,
# "american" nearest neighbors: in, for, and, from, some, at, these, were,
# "britain" nearest neighbors: became, come, thought, possible, UNK, members, called, work,

# %%
from sklearn.manifold import TSNE
from matplotlib import pylab

num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(embedding[1:num_points+1, :])

def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                        ha='right', va='bottom')
    pylab.show()

words = [id2word[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
